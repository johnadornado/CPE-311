# %% [markdown]
# <a href="https://colab.research.google.com/github/johnadornado/CPE-311/blob/main/Seatwork_6_1_Exploratory_Data_Analysis_on_Your_Own_Dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seatwork 6.1
# **CPE311 Computational Thinking with Python** <br>
# Name: Adornado, john louie V. <br>
# Section: CPE22S3  <br>

# %% [markdown]
# #Pandas for Data Analysis
# • Load the diabetes.csv file. Convert the diabetes.csv into dataframe <br>
# • Perform the following tasks in the diabetes dataframe:<br>
# • Identify the column names<br>
# • Identify the data types of the data<br>
# • Display the total number of records<br>
# • Display the first 20 records<br>
# • Display the last 20 records<br>
# • Change the Outcome column to DiagnosisIn [ ]:<br>
# • Create a new column Classification that display "Diabetes" if the value of outcome is 1 , otherwise "No Diabetes"<br>
# • Create a new dataframe "withDiabetes" that gathers data with diabetes<br>
# • Create a new dataframe "noDiabetes" thats gathers data with no diabetes<br>
# • Create a new dataframe "Pedia" that gathers data with age 0 to 19<br>
# • Create a new dataframe "Adult" that gathers data with age greater than 19<br>
# • Use numpy to get the average age and glucose value.<br>
# • Use numpy to get the median age and glucose value.<br>
# • Use numpy to get the middle values of glucose and age.<br>
# • Use numpy to get the standard deviation of the skinthickness.<br>

# %%
import pandas as pd
import numpy as np

p_data = pd.read_csv("cleaned_all_phones.csv")
p_data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %% [markdown]
# #Identify the column names

# %%
p_data.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %% [markdown]
# # Identify the data types of the data

# %%
p_data.dtypes
# Out:
# phone_name            object
# brand                 object
# os                    object
# inches               float64
# resolution            object
# battery                int64
# battery_type          object
# ram(GB)                int64
# announcement_date     object
# weight(g)            float64
# storage(GB)            int64
# video_720p              bool
# video_1080p             bool
# video_4K                bool
# video_8K                bool
# video_30fps             bool
# video_60fps             bool
# video_120fps            bool
# video_240fps            bool
# video_480fps            bool
# video_960fps            bool
# price(USD)           float64
# dtype: object

# %% [markdown]
# #Display the total number of records

# %%
print("total records of phone prices: ", len(p_data))
# Out:
# total records of phone prices:  1512

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

phones = pd.read_csv('cleaned_all_phones.csv')

plt.figure(figsize=(12, 6))
sns.violinplot(x='brand', y='price(USD)', data=phones)
plt.xticks(rotation=60)
plt.title('Price Distribution Across Different Phone Brands')
plt.show()

# %% [markdown]
# #Display the first 20 records

# %%
p_data.head(20)
# Out:
#            phone_name    brand             os  inches resolution  battery  \
# 0        Y6II Compact   Huawei    Android 5.1    5.00   720x1280     2200
# 1            K20 plus       LG    Android 7.0    5.30   720x1280     2700
# 2      P8 Lite (2017)   Huawei    Android 7.0    5.20  1080x1920     3000
# 3        Redmi Note 4   Xiaomi    Android 6.0    5.50  1080x1920     4100
# 4                 P10   Huawei    Android 7.0    5.10  1080x1920     3200
# 5          Xperia XA1     Sony    Android 7.0    5.00   720x1280     2300
# 6            P10 Lite   Huawei    Android 7.0    5.20  1080x1920     3000
# 7            P10 Plus   Huawei    Android 7.0    5.50  1440x2560     3750
# 8    Xperia XA1 Ultra     Sony    Android 7.0    6.00  1080x1920     2700
# 9            X power2       LG    Android 7.0    5.50   720x1280     4500
# 10      Redmi Note 4X   Xiaomi    Android 6.0    5.50  1080x1920     4100
# 11         Xperia XZs     Sony    Android 7.1    5.20  1080x1920     2900
# ...

# %% [markdown]
# #Display the last 20 records

# %%
p_data.tail(20)
# Out:
#               phone_name    brand          os  inches resolution  battery  \
# 1492  Legion Y700 (2023)   Lenovo  Android 13    8.80  1600x2560     6550
# 1493                 C51   Realme  Android 13    6.74   720x1600     5000
# 1494                 K11     Oppo  Android 13    6.70  1080x2400     5000
# 1495              A58 4G     Oppo  Android 13    6.72  1080x2400     5000
# 1496      Galaxy Z Flip5  Samsung  Android 13    6.70  1080x2640     3700
# 1497      Galaxy Z Fold5  Samsung  Android 13    7.60  1812x2176     4400
# 1498                 X6a    Honor  Android 13    6.56   720x1612     5200
# 1499               11 5G   Realme  Android 13    6.72  1080x2400     5000
# 1500               11 4G   Realme  Android 12    6.40  1080x2400     5000
# 1501         Redmi 12 5G   Xiaomi  Android 13    6.79  1080x2460     5000
# 1502         Poco M6 Pro   Xiaomi  Android 13    6.79  1080x2460     5000
# 1503          Galaxy F34  Samsung  Android 13    6.50  1080x2340     6000
# ...

# %% [markdown]
# # Change the Battery column to mAh [ ]:

# %%
p_data.rename(columns = {'battery': 'mAh'}, inplace = True)
p_data
# Out:
#             phone_name   brand           os  inches resolution   mAh  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280  2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280  2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920  3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920  4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920  3200
# ...                ...     ...          ...     ...        ...   ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388  5000
# 1508               11x  Realme   Android 13    6.72  1080x2400  5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772  5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772  4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400  4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %% [markdown]
# #Create a new column Classification that display "price(PHP)" if the value of outcome is price(USD)

# %%
usd_to_php = 55
p_data['price(PHP)'] = p_data['price(USD)'] * usd_to_php
p_data
# Out:
#             phone_name   brand           os  inches resolution   mAh  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280  2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280  2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920  3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920  4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920  3200
# ...                ...     ...          ...     ...        ...   ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388  5000
# 1508               11x  Realme   Android 13    6.72  1080x2400  5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772  5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772  4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400  4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_4K  \
# ...

# %% [markdown]
# #Create a new dataframe "HighRam" that gathers data with ram(GB) greater than or equal to 15

# %%
p_data = pd.DataFrame(p_data)
HighRam = p_data[p_data['ram(GB)'] >= 15].copy()

HighRam
# Out:
#                phone_name    brand          os  inches resolution   mAh  \
# 468      Galaxy S20 Ultra  Samsung  Android 10    6.90  1440x3200  5000
# 470   Galaxy S20 Ultra 5G  Samsung  Android 10    6.90  1440x3200  5000
# 612           Legion Duel   Lenovo  Android 10    6.65  1080x2340  5000
# 752   Galaxy S21 Ultra 5G  Samsung  Android 11    6.80  1440x3200  5000
# 778           Mi Mix Fold   Xiaomi  Android 10    8.01  1860x2480  5020
# 829          Legion 2 Pro   Lenovo  Android 11    6.92  1080x2460  5500
# 830         Legion Duel 2   Lenovo  Android 11    6.92  1080x2460  5500
# 1084           Legion Y90   Lenovo  Android 12    6.92  1080x2460  5600
# 1243              Ace Pro  OnePlus  Android 12    6.70  1080x2412  4800
# 1324    Magic Vs Ultimate    Honor  Android 12    7.90  1984x2272  5000
# 1329            Reno9 Pro     Oppo  Android 13    6.70  1080x2412  4500
# 1330           Reno9 Pro+     Oppo  Android 13    6.70  1080x2412  4700
# ...

# %% [markdown]
# #Display the total records of High ram phones

# %%
print("total records of High ram(GB)phone: ", len(HighRam))
# Out:
# total records of High ram(GB)phone:  35

# %% [markdown]
# #Display all the mid range phones available in the data set in php

# %%
p_data = pd.DataFrame(p_data)

midrange = 25000
f = p_data[p_data['price(PHP)'] <= midrange]
print("price(PHP)\tphone_name")
for i, row in f.iterrows():
    print("₱{:.0f}\t\t{}".format(row['price(PHP)'], row['phone_name']))
# Out:
# price(PHP)	phone_name
# ₱6600		Y6II Compact
# ₱5500		K20 plus
# ₱23100		P8 Lite (2017)
# ₱8250		Redmi Note 4
# ₱23100		P10
# ₱7700		Xperia XA1
# ₱23100		P10 Lite
# ₱9350		P10 Plus
# ₱13750		Xperia XA1 Ultra
# ₱9350		X power2
# ₱7150		Redmi Note 4X
# ₱12100		Xperia XZs
# ₱17600		Xperia XZ Premium
# ₱6050		Xperia L1
# ₱13750		A39
# ₱13750		F3 Plus
# ₱19250		Galaxy Xcover 4
# ₱9350		Galaxy J7 V
# ₱19250		Galaxy S8+
# ₱9350		K7 (2017)
# ₱15400		Y5 (2017)
# ₱8800		Harmony
# ₱18150		Mi 6
# ₱13200		Y6 (2017)
# ₱4950		Y7
# ₱8800		nova 2 plus
# ₱7700		nova 2
# ₱12650		Y3 (2017)
# ₱13200		Z4
# ₱11000		Mi Max 2
# ₱6050		Redmi 4 (4X)
# ₱4950		Stylo 3 Plus
# ₱13750		F3
# ₱9900		X venture
# ₱13750		A77 (Mediatek)
# ₱13750		R11
# ₱13750		R11 Plus
# ₱11000		Galaxy J7 Max
# ₱7150		Galaxy J7 (2017)
# ₱11000		Galaxy J7 Pro
# ₱4400		Galaxy J5 (2017)
# ₱7150		Y7 Prime
# ₱13750		A77 (2017)
# ₱6050		Q8 (2017)
# ₱11000		Q6
# ₱23650		Galaxy Folder2
# ₱11000		Galaxy Note FE
# ₱13750		P9 lite mini
# ...

# %% [markdown]
# #Display all the high end phone

# %%
dfm = pd.DataFrame(p_data)

midrange = 25000
highend = dfm[dfm['price(PHP)'] >= midrange]
f = highend
print("price(PHP)\tphone_name")
for i, row in f.iterrows():
    print("₱{:.0f}\t\t{}".format(row['price(PHP)'], row['phone_name']))
# Out:
# price(PHP)	phone_name
# ₱27500		Galaxy S8 Active
# ₱26400		A71
# ₱30250		Galaxy C7 (2017)
# ₱27500		Galaxy J2 (2017)
# ₱33550		Pixel 2
# ₱28600		Pixel 2 XL
# ₱27500		A83
# ₱27500		X4+
# ₱33000		Y9 (2018)
# ₱31900		F7
# ₱25300		Xperia XZ2 Premium
# ₱71500		Y3 (2018)
# ₱25300		A3s
# ₱28050		F9 (F9 Pro)
# ₱28050		Xperia XZ3
# ₱28050		Mi 8 Pro
# ₱31350		iPhone XS Max
# ₱40150		Mi Mix 3
# ₱25300		Mate 20 RS Porsche Design
# ₱74250		K1
# ₱30250		Magic 2
# ₱44000		Enjoy 9
# ₱30250		Galaxy A8s
# ₱66000		nova 4
# ₱38500		6T McLaren
# ₱31900		P smart 2019
# ₱29150		Mi 9 Explorer
# ₱32450		Mi 9
# ₱25300		Mi 9 SE
# ₱26400		V50 ThinQ 5G
# ₱27500		Xperia 1
# ₱30800		Xperia 10 Plus
# ₱33000		F11
# ₱33000		Magic 2 3D
# ₱25300		F11 Pro
# ₱25850		Reno Z
# ₱25850		20 Pro
# ₱32450		7 Pro
# ₱44000		7 Pro 5G
# ₱36850		P20 lite (2019)
# ₱30250		Stylo 5
# ₱25300		Mi 9T
# ₱30250		Black Shark 2 Pro
# ₱41800		Y9 Prime (2019)
# ₱60500		Galaxy Note10+ 5G
# ₱32450		Galaxy Note10+
# ₱38500		Galaxy A30s
# ...

# %% [markdown]
# #Display a specific brand

# %%
p_data = pd.DataFrame(p_data)
brand_a = p_data[p_data['brand'] == 'Apple']
brand_a
# Out:
#              phone_name  brand          os  inches resolution   mAh  \
# 62             iPhone 8  Apple      iOS 11     4.7   750x1334  1821
# 63             iPhone X  Apple  iOS 11.1.1     5.8  1125x2436  2716
# 201       iPhone XS Max  Apple      iOS 12     6.5  1242x2688  3174
# 202           iPhone XS  Apple      iOS 12     5.8  1125x2436  2658
# 203           iPhone XR  Apple      iOS 12     6.1   828x1792  2942
# 398   iPhone 11 Pro Max  Apple      iOS 13     6.5  1242x2688  3969
# 399       iPhone 11 Pro  Apple      iOS 13     5.8  1125x2436  3046
# 400           iPhone 11  Apple      iOS 13     6.1   828x1792  3110
# 536    iPhone SE (2020)  Apple      iOS 13     4.7   750x1334  1821
# 695       iPhone 12 Pro  Apple    iOS 14.1     6.1  1170x2532  2815
# 696           iPhone 12  Apple    iOS 14.1     6.1  1170x2532  2815
# 697   iPhone 12 Pro Max  Apple    iOS 14.1     6.7  1284x2778  3687
# 701      iPhone 12 mini  Apple    iOS 14.1     5.4  1080x2340  2227
# ...

# %% [markdown]
# #Use numpy to get the average of inch and prices of phones

# %%
m_usd = np.mean(p_data['price(USD)'])
m_php = np.mean(p_data['price(PHP)'])
m_inch = np.mean(p_data['inches'])

print("Average prices of phone in USD: ${:.2f}".format(m_usd))
print("Average prices of phone in PHP: ₱{:.2f}".format(m_php))
print("Average inch of phone in the dataset: {:.2f}".format(m_inch))
# Out:
# Average prices of phone in USD: $337.85
# Average prices of phone in PHP: ₱18581.59
# Average inch of phone in the dataset: 6.42

# %% [markdown]
# #Use numpy to get the Median inches and prices of phone.

# %%
m_usd = np.median(p_data['price(USD)'])
m_php = np.median(p_data['price(PHP)'])
m_inch = np.median(p_data['inches'])

print("Median prices of phone in USD: ${:.2f}".format(m_usd))
print("Median prices of phone in PHP: ₱{:.2f}".format(m_php))
print("Median inch of phone in the dataset: {:.2f}".format(m_inch))
# Out:
# Median prices of phone in USD: $260.00
# Median prices of phone in PHP: ₱14300.00
# Median inch of phone in the dataset: 6.50

# %% [markdown]
# #Use numpy to get the middle values of inches of phone.

# %%
m_usd = np.median(p_data['price(USD)'])
m_php = np.median(p_data['price(PHP)'])
m_inch = np.median(p_data['inches'])

print("Median prices of phone in USD: ${:.2f}".format(m_usd))
print("Median prices of phone in PHP: ₱{:.2f}".format(m_php))
print("Median inch of phone in the dataset: {:.2f}".format(m_inch))
# Out:
# Median prices of phone in USD: $260.00
# Median prices of phone in PHP: ₱14300.00
# Median inch of phone in the dataset: 6.50

# %% [markdown]
# #Use numpy to get the standard deviation of the phone prices.

# %%
std_usd = np.std(p_data['price(USD)'])
std_php = np.std(p_data['price(PHP)'])


print("standard deviation prices of phone in USD: ${:.2f}".format(std_usd))
print("standard deviation prices of phone in PHP: ₱{:.2f}".format(std_php))
# Out:
# standard deviation prices of phone in USD: $266.65
# standard deviation prices of phone in PHP: ₱14665.89
