# %% [markdown]
# <a href="https://colab.research.google.com/github/johnadornado/CPE-311/blob/main/Seatwork_6_1_Exploratory_Data_Analysis_on_Your_Own_Dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas for Data Analysis
# • Load the diabetes.csv file. Convert the diabetes.csv into dataframe <br>
# • Perform the following tasks in the diabetes dataframe:<br>
# • Identify the column names<br>
# • Identify the data types of the data<br>
# • Display the total number of records<br>
# • Display the first 20 records<br>
# • Display the last 20 records<br>
# • Change the Outcome column to DiagnosisIn [ ]:<br>
# • Create a new column Classification that display "Diabetes" if the value of outcome is 1 , otherwise "No Diabetes"<br>
# • Create a new dataframe "withDiabetes" that gathers data with diabetes<br>
# • Create a new dataframe "noDiabetes" thats gathers data with no diabetes<br>
# • Create a new dataframe "Pedia" that gathers data with age 0 to 19<br>
# • Create a new dataframe "Adult" that gathers data with age greater than 19<br>
# • Use numpy to get the average age and glucose value.<br>
# • Use numpy to get the median age and glucose value.<br>
# • Use numpy to get the middle values of glucose and age.<br>
# • Use numpy to get the standard deviation of the skinthickness.<br>

# %%
import pandas as pd
import numpy as np

p_data = pd.read_csv("cleaned_all_phones.csv")
p_data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %% [markdown]
# #Identify the column names

# %%
p_data.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %% [markdown]
# # Identify the data types of the data

# %%
p_data.dtypes
# Out:
# phone_name            object
# brand                 object
# os                    object
# inches               float64
# resolution            object
# battery                int64
# battery_type          object
# ram(GB)                int64
# announcement_date     object
# weight(g)            float64
# storage(GB)            int64
# video_720p              bool
# video_1080p             bool
# video_4K                bool
# video_8K                bool
# video_30fps             bool
# video_60fps             bool
# video_120fps            bool
# video_240fps            bool
# video_480fps            bool
# video_960fps            bool
# price(USD)           float64
# dtype: object

# %% [markdown]
# #Display the total number of records

# %%
print("total records of phone prices: ", len(p_data))
# Out:
# total records of phone prices:  1512

# %% [markdown]
# #Display the first 20 records

# %%
p_data.head(20)
# Out:
#            phone_name    brand             os  inches resolution  battery  \
# 0        Y6II Compact   Huawei    Android 5.1    5.00   720x1280     2200
# 1            K20 plus       LG    Android 7.0    5.30   720x1280     2700
# 2      P8 Lite (2017)   Huawei    Android 7.0    5.20  1080x1920     3000
# 3        Redmi Note 4   Xiaomi    Android 6.0    5.50  1080x1920     4100
# 4                 P10   Huawei    Android 7.0    5.10  1080x1920     3200
# 5          Xperia XA1     Sony    Android 7.0    5.00   720x1280     2300
# 6            P10 Lite   Huawei    Android 7.0    5.20  1080x1920     3000
# 7            P10 Plus   Huawei    Android 7.0    5.50  1440x2560     3750
# 8    Xperia XA1 Ultra     Sony    Android 7.0    6.00  1080x1920     2700
# 9            X power2       LG    Android 7.0    5.50   720x1280     4500
# 10      Redmi Note 4X   Xiaomi    Android 6.0    5.50  1080x1920     4100
# 11         Xperia XZs     Sony    Android 7.1    5.20  1080x1920     2900
# ...

# %% [markdown]
# #Display the last 20 records

# %%
p_data.tail(20)
# Out:
#               phone_name    brand          os  inches resolution  battery  \
# 1492  Legion Y700 (2023)   Lenovo  Android 13    8.80  1600x2560     6550
# 1493                 C51   Realme  Android 13    6.74   720x1600     5000
# 1494                 K11     Oppo  Android 13    6.70  1080x2400     5000
# 1495              A58 4G     Oppo  Android 13    6.72  1080x2400     5000
# 1496      Galaxy Z Flip5  Samsung  Android 13    6.70  1080x2640     3700
# 1497      Galaxy Z Fold5  Samsung  Android 13    7.60  1812x2176     4400
# 1498                 X6a    Honor  Android 13    6.56   720x1612     5200
# 1499               11 5G   Realme  Android 13    6.72  1080x2400     5000
# 1500               11 4G   Realme  Android 12    6.40  1080x2400     5000
# 1501         Redmi 12 5G   Xiaomi  Android 13    6.79  1080x2460     5000
# 1502         Poco M6 Pro   Xiaomi  Android 13    6.79  1080x2460     5000
# 1503          Galaxy F34  Samsung  Android 13    6.50  1080x2340     6000
# ...

# %% [markdown]
# # Change the Battery column to mAh [ ]:

# %%
p_data.rename(columns = {'battery': 'mAh'}, inplace = True)
p_data
# Out:
#             phone_name   brand           os  inches resolution   mAh  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280  2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280  2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920  3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920  4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920  3200
# ...                ...     ...          ...     ...        ...   ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388  5000
# 1508               11x  Realme   Android 13    6.72  1080x2400  5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772  5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772  4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400  4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %% [markdown]
# #Create a new column Classification that display "price(PHP)" if the value of outcome is price(USD)

# %%
usd_to_php = 55
p_data['price(PHP)'] = p_data['price(USD)'] * usd_to_php
p_data
# Out:
#             phone_name   brand           os  inches resolution   mAh  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280  2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280  2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920  3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920  4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920  3200
# ...                ...     ...          ...     ...        ...   ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388  5000
# 1508               11x  Realme   Android 13    6.72  1080x2400  5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772  5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772  4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400  4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_4K  \
# ...

# %% [markdown]
# #Create a new dataframe "HighRam" that gathers data with ram(GB) greater than 16

# %%
p_data = pd.DataFrame(p_data)
HighRam = p_data[p_data['ram(GB)'] > 16].copy()

HighRam
# Out:
#            phone_name    brand          os  inches resolution   mAh  \
# 829      Legion 2 Pro   Lenovo  Android 11    6.92  1080x2460  5500
# 1084       Legion Y90   Lenovo  Android 12    6.92  1080x2460  5600
# 1505  Redmi K60 Ultra   Xiaomi  Android 13    6.67  1220x2712  5000
# 1506        Ace 2 Pro  OnePlus  Android 13    6.74  1240x2772  5000
# 1510         GT5 240W   Realme  Android 13    6.74  1240x2772  4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_4K  \
# 829         Li-Po       18        2021-04-08      259.0  ...      True
# 1084        Li-Po       18        2022-03-01      252.0  ...      True
# 1505        Li-Po       24        2023-08-15      204.0  ...      True
# 1506        Li-Po       24        2023-08-16      210.0  ...      True
# 1510        Li-Po       24        2023-08-28      205.0  ...      True
#
#       video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %% [markdown]
# #Use numpy to get the mean of inches of phone

# %%
mean_inch = np.mean(p_data['inches'])

print("Average inches of phone: ", mean_inch)
# Out:
# Average inches of phone:  6.4224603174603185

# %% [markdown]
# #Use numpy to get the Median inches of phone.

# %%
median_inch = np.median(p_data['inches'])

print("Median inches of phone: ", mean_inch)
# Out:
# Median inches of phone:  6.4224603174603185

# %% [markdown]
# #Use numpy to get the middle values of glucose and age.

# %%
median_inch = np.median(p_data['inches'])

print("Median inches of phone: ", mean_inch)
# Out:
# Median inches of phone:  6.4224603174603185

# %% [markdown]
# #Use numpy to get the standard deviation of the ram(GB).

# %%
ram_std = np.std(p_data['ram(GB)'])

print("Standard deviation of the ram(GB): ", ram_std)
# Out:
# Standard deviation of the skinthickness:  2.7005396094361878
